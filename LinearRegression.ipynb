# %%
import pandas as pd
import numpy as np

df = pd.read_csv('YearPredictionMSD.txt', header=None)
df
# Out:
#           0         1         2         3         4         5         6   \
# 0       2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905
# 1       2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777
# 2       2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940
# 3       2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683
# 4       2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409
# ...      ...       ...       ...       ...       ...       ...       ...
# 515340  2006  51.28467  45.88068  22.19582  -5.53319  -3.61835 -16.36914
# 515341  2006  49.87870  37.93125  18.65987  -3.63581 -27.75665 -18.52988
# 515342  2006  45.12852  12.65758 -38.72018   8.80882 -29.29985  -2.28706
# 515343  2006  44.16614  32.38368  -3.34971  -2.49165 -19.59278 -18.67098
# 515344  2005  51.85726  59.11655  26.39436  -5.46030 -20.69012 -19.95528
#
#               7         8         9   ...        81         82         83  \
# ...

# %%
print(len(df.columns))
# X = df[df.columns[1:]].values
# 1 and 2 are skewed data
# X = df[set(df.columns) - set(df.columns[0:3]) - set(df.columns[21:25]) - set(df.columns[53:54])].values
X = df[set(df.columns) - set(df.columns[0:1]) - set(df.columns[21:25])].values # - set(df.columns[53:54])].values
Y=df[df.columns[0]]
# Out:
# 91

# %%
#Transform the data in training and testing
# X,Y = shuffle(X,Y,random_state=1)
# train_x,test_x,train_y,test_y = train_test_split(X,Y,test_size=0.20, random_state=42)
for idx in range(X.shape[1]):
    X[:,idx]=X[:,idx]/max(X[:,idx])
#     print(max(X[:,idx]))
X
# Out:
# array([[ 8.05929598e-01,  5.59048577e-02,  2.26350244e-01, ...,
#         -3.93213924e-03, -3.71459488e-03,  3.33865059e-03],
#        [ 7.86381151e-01,  4.79847551e-02,  2.17830195e-01, ...,
#          2.60010854e-02,  7.90360894e-03,  3.97117933e-02],
#        [ 8.22285378e-01,  8.29441877e-02,  1.72892250e-01, ...,
#         -1.26429725e-04,  5.36568945e-03, -9.78684706e-04],
#        ...,
#        [ 7.28230080e-01,  3.29568066e-02, -1.19931883e-01, ...,
#         -1.31019735e-02,  7.29883428e-03, -1.19392896e-02],
#        [ 7.12700342e-01,  8.43180671e-02, -1.03753916e-02, ...,
#          4.38531395e-02,  2.00598820e-03,  5.86356567e-02],
#        [ 8.36810438e-01,  1.53923002e-01,  8.17538891e-02, ...,
#         -1.19009235e-02,  4.37633928e-03,  1.79577027e-02]])

# %%
# train_x=X[:463715]
# test_x=X[463716:]
# train_y=Y[:463715]
# test_y=Y[463716:]
train_x=X[:1000]
test_x=X[-200:]
train_y=Y[:1000]
test_y=Y[-200:]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(train_x, train_y)

#fitting the polynomial regression model to the dataset
# from sklearn.preprocessing import PolynomialFeatures
# poly_reg=PolynomialFeatures(degree=2)
# X_poly=poly_reg.fit_transform(train_x)
# poly_reg.fit(X_poly,train_y)
# model=LinearRegression()
# model.fit(X_poly,train_y)

# %%
# r_sq = model.score(train_x, train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-782fb3b9381d> in <module>
# ----> 1 r_sq = model.score(train_x, train_y)
#
# ~\.conda\envs\tensor\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     549
#     550         from .metrics import r2_score
# --> 551         y_pred = self.predict(X)
#     552         return r2_score(y, y_pred, sample_weight=sample_weight)
#     553
#
# ~\.conda\envs\tensor\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\.conda\envs\tensor\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     217
# ...

# %%
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7ec9ce908401> in <module>
# ----> 1 print('coefficient of determination:', r_sq)
#       2 print('intercept:', model.intercept_)
#       3 print('slope:', model.coef_)
#
# NameError: name 'r_sq' is not defined

# %%
y_pred = model.predict(test_x)
y_pred = np.around(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-98112ed028e6> in <module>
# ----> 1 y_pred = model.predict(test_x)
#       2 y_pred = np.around(y_pred)
#
# ~\.conda\envs\tensor\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\.conda\envs\tensor\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#     221
#
# ...

# %%
print('predicted response:', y_pred, sep='\n')
print('actual response:', test_y, sep='\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a31f64a77acf> in <module>
# ----> 1 print('predicted response:', y_pred, sep='\n')
#       2 print('actual response:', test_y, sep='\n')
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test_y,y_pred)

# %%
len([0 for ele in test_y-y_pred if ele==0])/len(y_pred)*100

# %%
from sklearn.metrics import plot_confusion_matrix
import seaborn as sis
import matplotlib.pyplot as plt

# %%
df_cm = pd.DataFrame(confusion_matrix(test_y,y_pred), 
                     range(confusion_matrix(test_y,y_pred).shape[0]), 
                     range(confusion_matrix(test_y,y_pred).shape[1]))
# plt.figure(figsize=(10,7))
sis.set(font_scale=1.4) # for label size
sis.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size

plt.show()

# %%
print(test_x.shape)
train_x.shape
# AIM of project
# Data description
# Work Environment: Programming language, python, etc i.e. resource requirement
# Divide code into various steps: 
# 1. Preprocessing
# 2. Algorithm selection
# 3. model preparation - train-test splt, etc
# 4. testing of the model
# 5. Conclusions
# Comparison among models
# Conclusion 
# Discussions
